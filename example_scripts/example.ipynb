# %%
import datumlib as dl
import numpy as np
import datetime

# %%
# generate some random signals
class_pool = ["A", "B", "C"]
operator_pool = ["John", "Bob", "Alice"]
sampling_rate = 44100
xs = [
    dl.datum(
        np.random.normal(0, 1, 44100),
        tags={
            "class": np.random.choice(class_pool),
            "operator": np.random.choice(operator_pool),
        },
    )
    for _ in range(5)
]

collection = dl.collect(
    *xs,
    tags={
        "date": datetime.date.today(),
        "time": datetime.datetime.now().strftime("%H:%M:%S"),
    },
)
dl.display_collection(collection)
# Out:
# ╭──────────────────────────────────────────────── DatumCollection ────────────────────────────────────────────────╮
# │ Collection Tags                                                                                                 │
# │ date  2026-02-13                                                                                                │
# │ time  15:08:31                                                                                                  │
# │ entries (5)                                                                                                     │
# │ ├── Datum 0                                                                                                     │
# │ │   ├── data: array([ 0.05627779,  1.45275675, -0.77052434, ...,  0.06859577,                                   │
# │ │   │           0.89389031, -0.10354962], shape=(44100,))                                                       │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: C                                                                                            │
# │ │       └── operator: John                                                                                      │
# │ ├── Datum 1                                                                                                     │
# │ │   ├── data: array([-0.04676306,  0.2435719 ,  0.46136197, ..., -0.03760437,                                   │
# │ │   │           1.30456926, -0.87983725], shape=(44100,))                                                       │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: B                                                                                            │
# │ │       └── operator: John                                                                                      │
# │ ├── Datum 2                                                                                                     │
# │ │   ├── data: array([ 1.17325891, -0.13285367,  1.56416462, ...,  0.40100461,                                   │
# │ │   │          -0.68127517,  0.7731448 ], shape=(44100,))                                                       │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: B                                                                                            │
# │ │       └── operator: John                                                                                      │
# │ ├── Datum 3                                                                                                     │
# │ │   ├── data: array([ 0.64442659, -0.25837259,  0.24562357, ...,  0.10968467,                                   │
# │ │   │           1.36128214, -0.42609869], shape=(44100,))                                                       │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: C                                                                                            │
# │ │       └── operator: Alice                                                                                     │
# │ └── Datum 4                                                                                                     │
# │     ├── data: array([-0.79949225,  0.44107953,  0.61057424, ..., -1.45765823,                                   │
# │     │          -1.01446945,  0.56504931], shape=(44100,))                                                       │
# │     └── tags                                                                                                    │
# │         ├── class: B                                                                                            │
# │         └── operator: John                                                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from datumlib import collection_util as cu
# some data processing steps


def truncate(x: np.ndarray, sample_rate: int, operator: str) -> np.ndarray:
    return x


truncate_mapped = cu.cmap(truncate, pass_tags=True)


truncate_mapped(collection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 12
#       6     return x
#       9 truncate_mapped = cu.cmap(truncate, pass_tags=True)
# ---> 12 truncate_mapped(collection)
#
# File ~/ws/datumlib/src/datumlib/_collection_utils.py:60, in cmap.<locals>._collection_map(collection, *args, **kwargs)
#      57     if pass_tags:
#      58         call_kwargs["tags"] = collection.tags
# ---> 60     mapped_entries.append(func(x, *args, **call_kwargs))
#      62 return collect(*mapped_entries, tags=collection.tags)
#
# TypeError: truncate() got an unexpected keyword argument 'tags'
