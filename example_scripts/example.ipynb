# %%
import datumlib as dl
import numpy as np
import datetime

# %%
# generate some random signals
class_pool = ["A", "B", "C"]
operator_pool = ["John", "Bob", "Alice"]
sampling_rate = 44100
xs = [
    dl.datum(
        np.random.normal(0, 1, 44100),
        tags={
            "class": np.random.choice(class_pool),
            "operator": np.random.choice(operator_pool),
        },
    )
    for _ in range(5)
]

collection = dl.collect(
    *xs,
    tags={
        "date": datetime.date.today(),
        "time": datetime.datetime.now().strftime("%H:%M:%S"),
    },
)
dl.display_collection(collection)
# Out:
# ╭──────────────────────────────────────────────── DatumCollection ────────────────────────────────────────────────╮
# │ Collection Tags                                                                                                 │
# │ date  2026-02-16                                                                                                │
# │ time  16:49:13                                                                                                  │
# │ entries (5)                                                                                                     │
# │ ├── Datum 0                                                                                                     │
# │ │   ├── data: array([ 0.75144848, -0.72255369,  1.78692223, ..., -1.25336069,                                   │
# │ │   │           1.10768707, -1.1332865 ], shape=(44100,))                                                       │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: A                                                                                            │
# │ │       └── operator: Bob                                                                                       │
# │ ├── Datum 1                                                                                                     │
# │ │   ├── data: array([-0.26591435, -0.40542988,  0.51743458, ..., -1.65196146,                                   │
# │ │   │          -0.32510933, -0.2855654 ], shape=(44100,))                                                       │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: C                                                                                            │
# │ │       └── operator: John                                                                                      │
# │ ├── Datum 2                                                                                                     │
# │ │   ├── data: array([-2.43402793,  1.13520232, -0.86702317, ...,  0.57020983,                                   │
# │ │   │          -0.67417809, -2.23598588], shape=(44100,))                                                       │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: C                                                                                            │
# │ │       └── operator: Alice                                                                                     │
# │ ├── Datum 3                                                                                                     │
# │ │   ├── data: array([-1.22047275, -1.07364866, -0.89573679, ..., -0.00768682,                                   │
# │ │   │           0.73225725, -0.70917168], shape=(44100,))                                                       │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: A                                                                                            │
# │ │       └── operator: Bob                                                                                       │
# │ └── Datum 4                                                                                                     │
# │     ├── data: array([ 0.99894531,  1.83220339,  1.67732957, ..., -0.89962729,                                   │
# │     │          -0.03342332,  0.37349089], shape=(44100,))                                                       │
# │     └── tags                                                                                                    │
# │         ├── class: C                                                                                            │
# │         └── operator: John                                                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from datumlib import collection_util as cu
# some data processing steps


def truncate(x: np.ndarray, sample_rate: int, operator: str) -> np.ndarray:
    return x


truncate_mapped = cu.cmap(truncate, pass_tags=True)


truncate_mapped(collection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       5 def truncate(x: np.ndarray, sample_rate: int, operator: str) -> np.ndarray:
#       6     return x
# ----> 9 truncate_mapped = cu.cmap(truncate, pass_tags=True)
#      12 truncate_mapped(collection)
#
# TypeError: cmap() got an unexpected keyword argument 'pass_tags'
