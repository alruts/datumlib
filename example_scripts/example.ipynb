# %%
import datumlib as dl
import numpy as np
import datetime

# %%
# generate some random signals
class_pool = ["A", "B", "C"]
operator_pool = ["John", "Bob", "Alice"]
sample_rate = 44100
xs = [
    dl.datum(
        np.random.normal(0, 1, 44100),
        tags={
            "class": np.random.choice(class_pool),
            "operator": np.random.choice(operator_pool),
            "sample_rate": 44100,
        },
    )
    for _ in range(5)
]

collection = dl.collect(
    *xs,
    tags={
        "date": datetime.date.today(),
        "time": datetime.datetime.now().strftime("%H:%M:%S"),
    },
)
dl.display_collection(collection)
# Out:
# ╭──────────────────────────────────────────────── DatumCollection ────────────────────────────────────────────────╮
# │ Collection Tags                                                                                                 │
# │ date  2026-02-21                                                                                                │
# │ time  22:37:36                                                                                                  │
# │ entries (5)                                                                                                     │
# │ ├── Datum 0                                                                                                     │
# │ │   ├── data: array([0.78914759, 0.83940722, 0.66734413, ..., 1.04897023, 1.01113024,                           │
# │ │   │          0.21470896], shape=(44100,))                                                                     │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: A                                                                                            │
# │ │       ├── operator: John                                                                                      │
# │ │       └── sample_rate: 44100                                                                                  │
# │ ├── Datum 1                                                                                                     │
# │ │   ├── data: array([ 1.5880581 ,  0.45646618, -1.03606146, ..., -0.93717546,                                   │
# │ │   │          -1.96064405, -0.68329861], shape=(44100,))                                                       │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: B                                                                                            │
# │ │       ├── operator: Bob                                                                                       │
# │ │       └── sample_rate: 44100                                                                                  │
# │ ├── Datum 2                                                                                                     │
# │ │   ├── data: array([-0.61865082, -0.22530241, -2.490098  , ..., -0.29815578,                                   │
# │ │   │           0.30215889,  0.31611917], shape=(44100,))                                                       │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: A                                                                                            │
# │ │       ├── operator: Bob                                                                                       │
# │ │       └── sample_rate: 44100                                                                                  │
# │ ├── Datum 3                                                                                                     │
# │ │   ├── data: array([ 0.47488428,  1.83418567,  0.69407517, ..., -0.14050981,                                   │
# │ │   │          -0.81364039,  0.89019082], shape=(44100,))                                                       │
# │ │   └── tags                                                                                                    │
# │ │       ├── class: B                                                                                            │
# │ │       ├── operator: John                                                                                      │
# │ │       └── sample_rate: 44100                                                                                  │
# │ └── Datum 4                                                                                                     │
# │     ├── data: array([ 0.18314182,  0.88742524,  1.41728859, ..., -2.02106953,                                   │
# │     │           0.34841293,  1.62719379], shape=(44100,))                                                       │
# │     └── tags                                                                                                    │
# │         ├── class: A                                                                                            │
# │         ├── operator: Alice                                                                                     │
# │         └── sample_rate: 44100                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
